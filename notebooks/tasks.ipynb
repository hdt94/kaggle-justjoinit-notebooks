# %% [markdown]
# # Requerimientos (tareas)

# %% [markdown]
# El presente documento muestra el uso y los resultados obtenidos para los requerimientos dados, utilizando los algoritmos desarrollados.

# %% [markdown]
# ## Configuración inicial

# %% [markdown]
# Instancia de la clase `Analyst` que permite leer los datos en disco una única vez, mantener los datos en memoria, y calcular los requerimientos:

# %%
from Analyst import Analyst

analyst = Analyst()

# %% [markdown]
# Funcionalidades varias para este documento:

# %%
import os
from pprint import PrettyPrinter
from typing import List, Dict

import pandas as pd


pp = PrettyPrinter(indent=2)

def print_report(report: Dict):
    pp.pprint(report)

# función para mejorar la visualización
def records_to_dataframe(records: List[Dict]):
    return pd.DataFrame(records)

# %% [markdown]
# ## Lectura de datos

# %% [markdown]
# Directorio de datos:

# %%
# definir el directorio manualmente
# data_dir = "/home/user/kaggle-justjoinit/data"

# opcionalmente con una variable de ambiente
data_dir = os.environ.get("DATA_DIR")

# data_dir

# %% [markdown]
# Leer datos en disco y preservar en memoria:

# %%
report = analyst.read_data_dir(data_dir, prefix="small")

# %%
first_jobs = report.pop("records_first_jobs")
lastest_jobs = report.pop("records_latest_jobs")

# %%
print_report(report)
# Out:
# {'count_jobs': 114709}

# %%
records_to_dataframe(first_jobs)
# Out:
#                       published_at                                 title  \
# 0 2022-04-09 13:00:13.440000+00:00                     Flutter Developer
# 1 2022-04-09 13:00:13.440000+00:00         Performance Marketing Analyst
# 2 2022-04-09 13:00:13.440000+00:00  Senior Software Development Engineer
#
#                               company_name experience_level country_code  \
# 0  DO OK • Life-changing software services              mid           PL
# 1                              GetResponse              mid           PL
# 2                Amazon Development Centre           senior           PL
#
#        city
# 0   Wroclaw
# 1    Gdansk
# 2  Warszawa

# %%
records_to_dataframe(lastest_jobs)
# Out:
#                       published_at                             title  \
# 0        2023-09-01 18:20:00+00:00                      Scrum Master
# 1        2023-09-01 17:37:00+00:00  IT Business Intelligence Manager
# 2 2023-09-01 16:04:48.008000+00:00             Senior Java Developer
#
#                        company_name experience_level country_code     city
# 0  Sunrise System sp. z o.o. sp. k.              mid           PL  Wroclaw
# 1              Elis Textile Service              mid           PL   Gdansk
# 2                 Trimetis Services           senior           PL   Krakow

# %% [markdown]
# ## Requerimiento 1

# %%
report = analyst.requirement_1(2, "PL", "junior")
records = report.pop("records")
print_report(report)
# Out:
# {'count_jobs_junior': 8728, 'count_jobs_junior_PL': 8629}

# %%
records_to_dataframe(records)
# Out:
#                       published_at                             title  \
# 0 2023-09-01 16:00:10.800000+00:00         Junior Frontend Developer
# 1 2023-09-01 15:55:00.798000+00:00  Project Management Officer (PMO)
#
#   company_name experience_level country_code      city company_size  \
# 0       Softax           junior           PL  Warszawa    Undefined
# 1      Miquido           junior           PL    Krakow          200
#
#    open_to_hire_ukrainians
# 0                    False
# 1                    False

# %% [markdown]
# ## Requerimiento 2

# %%
report = analyst.requirement_2("Gazelle Global IT Recruitment", "2023-08-31", "2023-09-02")
records = report.pop("records")
print_report(report)
# Out:
# { 'count_jobs': 39,
#   'count_jobs_junior': 0,
#   'count_jobs_mid': 28,
#   'count_jobs_senior': 11}

# %%
records_to_dataframe(records)
# Out:
#                        published_at                             title  \
# 3               mid     Szczecin           PL           30         remote
# 4               mid       Poznan           PL           30         remote
# 5               mid       Krakow           PL           30         remote
# 6               mid     Katowice           PL           30         remote
# 7               mid       Poznan           PL           30         remote
# 8               mid       Gdansk           PL           30         remote
# 9               mid    Bialystok           PL           30         remote
# 10              mid     Warszawa           PL           30         remote
# 11              mid    Bialystok           PL           30         remote
# 12              mid     Katowice           PL           30         remote
# 13              mid       Gdansk           PL           30         remote
# 14              mid     Szczecin           PL           30         remote
# 15              mid     Warszawa           PL           30         remote
# 16           senior    Stockholm           SE           30         remote
# 17              mid      Wroclaw           PL           30  partly_remote
# 18           senior     Szczecin           PL           30         remote
# 19           senior       Poznan           PL           30         remote
# 20           senior     Helsinki           FI           30         remote
# 21           senior       Berlin           DE           30         remote
# 22           senior    Amsterdam           NL           30         remote
# 23           senior     Warszawa           PL           30         remote
# 24           senior      Wroclaw           PL           30         remote
# 25           senior       Krakow           PL           30         remote
# 26           senior       Gdansk           PL           30         remote
# 27           senior     Warszawa           PL           30         remote
# 28              mid         Lodz           PL           30         remote
# 29              mid       Poznan           PL           30         remote
# 30              mid     Szczecin           PL           30         remote
# 31              mid    Bialystok           PL           30         remote
# 32              mid     Katowice           PL           30         remote
# 33              mid     Warszawa           PL           30         remote
# 34              mid     Warszawa           PL           30         remote
# 35              mid      Wroclaw           PL           30         remote
# 36              mid       Gdansk           PL           30         remote
# 37              mid  Czestochowa           PL           30         remote
# 38              mid       Krakow           PL           30         remote
#
#     open_to_hire_ukrainians
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# 5                     False
# 6                     False
# 7                     False
# 8                     False
# 9                     False
# 10                    False
# 11                    False
# 12                    False
# 13                    False
# 14                    False
# 15                    False
# 16                    False
# 17                    False
# 18                    False
# 19                    False
# 20                    False
# 21                    False
# 22                    False
# 23                    False
# 24                    False
# 25                    False
# 26                    False
# 27                    False
# 28                    False
# 29                    False
# 30                    False
# 31                    False
# 32                    False
# 33                    False
# 34                    False
# 35                    False
# 36                    False
# 37                    False
# 38                    False

# %% [markdown]
# ## Requerimiento 3

# %%
report = analyst.requirement_3("PL", "2023-08-31", "2023-09-02")
records = report.pop("records")
print_report(report)
# Out:
# { 'city_least_jobs': 'Познань',
#   'city_most_jobs': 'Warszawa',
#   'count_cities': 152,
#   'count_companies': 527,
#   'count_jobs': 3940}

# %% [markdown]
# El campo "remote" se creó siendo verdadero si el campo "workplace_type" es igual al valor "remote", de lo contrario es falso:

# %%
records_to_dataframe(records)
# Out:
#                          published_at                                   title  \
# 0           2023-09-01 18:20:00+00:00                            Scrum Master
# 1           2023-09-01 17:37:00+00:00        IT Business Intelligence Manager
# 2    2023-09-01 16:04:48.008000+00:00                   Senior Java Developer
# 3    2023-09-01 16:04:44.051000+00:00                   Senior Java Developer
# 4    2023-09-01 16:04:41.344000+00:00                   Senior Java Developer
# ...                               ...                                     ...
# 3935        2023-08-31 06:22:00+00:00                       Angular Developer
# 3936 2023-08-31 06:00:11.023000+00:00                Senior Software Engineer
# 3937 2023-08-31 06:00:11.023000+00:00  Software Engineer (.NET) - Allegro Pay
# 3938 2023-08-31 06:00:11.023000+00:00                      Analityk Biznesowy
# 3939 2023-08-31 06:00:11.023000+00:00                   Tester Automatyzujacy
#
#      experience_level                      company_name      city  \
# 0                 mid  Sunrise System sp. z o.o. sp. k.   Wroclaw
# 1                 mid              Elis Textile Service    Gdansk
# 2              senior                 Trimetis Services    Krakow
# 3              senior                 Trimetis Services    Poznan
# 4              senior                 Trimetis Services  Warszawa
# ...               ...                               ...       ...
# 3935              mid                          nexocode    Krakow
# 3936           senior                      DevsData LLC  Warszawa
# 3937              mid                           Allegro  Warszawa
# 3938              mid                            Adamed    Krakow
# 3939           senior                          Currenda     Sopot
#
#      workplace_type  remote  open_to_hire_ukrainians
# 0            remote    True                    False
# 1     partly_remote   False                    False
# 2            remote    True                    False
# 3            remote    True                    False
# 4            remote    True                    False
# ...             ...     ...                      ...
# 3935         remote    True                    False
# 3936  partly_remote   False                    False
# 3937  partly_remote   False                    False
# 3938         remote    True                     True
# 3939         remote    True                    False
#
# [3940 rows x 8 columns]

# %% [markdown]
# ## Requerimiento 4

# %%
report = analyst.requirement_4(10, "2022-04-09", "2023-09-02", "junior", "US")
records = report.pop("records")
print_report(report)
# Out:
# { 'count_cities': 6,
#   'count_companies': 6,
#   'count_jobs': 10,
#   'least_jobs_city_count': 1.0,
#   'least_jobs_city_name': 'Torun',
#   'most_jobs_city_count': 5.0,
#   'most_jobs_city_name': 'Krakow',
#   'salary_mean': 7131.25}

# %%
records_to_dataframe(records)
# Out:
#    count_jobs  count_companies  most_jobs_company_count  \
# 0           1                1                        1
# 1           3                2                        2
# 2           1                1                        1
# 3           1                1                        1
# 4           3                3                        1
# 5           1                1                        1
#
#   most_jobs_company_name  salary_best  salary_mean  salary_worst
# 0                    GMS       7500.0       6750.0        6000.0
# 1                Miquido       8400.0       6600.0        4900.0
# 2                    GMS       7500.0       6750.0        6000.0
# 3                  Posti          NaN          NaN           NaN
# 4                 Softax      12000.0       8500.0        6000.0
# 5                    GMS       7500.0       6750.0        6000.0

# %% [markdown]
# ## Requerimiento 5

# %%
report = analyst.requirement_5(4, "2022-04-09", "2023-09-02")
stats = report.pop("stats_per_level")
print_report(report)
# Out:
# { 'count_cities': 888,
#   'count_jobs': 112553,
#   'most_jobs_country_count': 111209,
#   'most_jobs_country_name': 'PL'}

# %%
records_to_dataframe([{"experience_level": key, **values} for (key, values) in stats.items()])
# Out:
#   experience_level  count_companies_with_location  \
# 0           junior                           2029
# 1              mid                           4472
# 2           senior                           3005
#
#    count_companies_without_location  count_unique_skills  \
# 0                                 0                 1646
# 1                                 0                 5604
# 2                                 0                 4367
#
#    most_required_skill_count most_required_skill_name  \
# 0                       1261                  ENGLISH
# 1                       6011                     JAVA
# 2                       5276                     JAVA
#
#    least_required_skill_count least_required_skill_name  minimum_skills_level  \
# 0                           1             DOCUMENTATION              2.219012
# 1                           1      GOOGLE ANALYTICS 360              3.249139
# 2                           1                       QMS              3.872120
#
#    count_companies  most_jobs_company_count most_jobs_company_name  \
# 0             2029                      265                Dataedo
# 1             4472                     1328                  Nokia
# 2             3005                     1620                  WIPRO
#
#    least_jobs_company_count least_jobs_company_name
# 0                         1     Macrobond Financial
# 1                         1               DealStack
# 2                         1       TP Servglobal Ltd
